# %%
import pvdeg
import pandas as pd

# %%
# The goal of this notebook is to create preset lists of NSRDB points for users.

# %%
location_getter = pvdeg.GeospatialScenario()

location_getter.addLocation(country="United States")
# Out:
# /home/tford/.conda-envs/rpp/lib/python3.10/site-packages/xarray/core/dataset.py:274: UserWarning: The specified chunks separate the stored chunks along dimension "phony_dim_1" starting at index 500. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(

# %%
location_getter.plot_coords()
# Out:
# (<Figure size 1500x1000 with 1 Axes>,
#  <GeoAxes: title={'center': "Coordinate Pairs from '311024' Meta Data"}>)

# %%
location_getter
# Out:
#         <div style="border:1px solid #ddd; border-radius: 5px; padding: 3px; margin-top: 5px;">
#             <h2>311024: Scenario Analysis</h2>
#             <p><strong>Path:</strong> <a href="file:////home/tford/dev/PVDegradationTools/points/pvd_job_311024" target="_blank">/home/tford/dev/PVDegradationTools/points/pvd_job_311024</a></p>
#             <p><strong>HPC Configuration:</strong> False</p>
#             <p><strong>GIDs:</strong> [    590     645     646 ... 1465862 1465864 1465865]</p>
#             <div>
#                 <h3>Results</h3>
#                 None
#             </div>
#             <div>
#                 <h3>Pipeline</h3>
#                 <div></div>
#             </div>
#             <div>
#                 <h3>Modules</h3>
#                 <div></div>
#             </div>
#             <div>
#                 <h3>Weather Dataset</h3>
#
# ...

# %%
sizes = [200000, 100000, 50000, 25000, 12500]

original_size = location_getter.meta_data.shape[0]

props = []

for size in sizes:
    props.append(size / original_size)

print(props)
# Out:
# [0.3656721602814213, 0.18283608014071065, 0.09141804007035532, 0.04570902003517766, 0.02285451001758883]

# %%
Tree = pvdeg.geospatial.meta_KDtree(meta_df=location_getter.meta_data)

# %%
location_getter.downselect_elevation_stochastic(kdtree = Tree, downselect_prop=prop)

# %%
for i in range(len(props)):

    location_getter = pvdeg.GeospatialScenario()
    location_getter.addLocation(country="United States")

    Tree = pvdeg.geospatial.meta_KDtree(meta_df=location_getter.meta_data)

    location_getter.downselect_elevation_stochastic(kdtree = Tree, downselect_prop=props[i])

    location_getter.meta_data.to_csv(f"USA-{sizes[i]}.csv")
# Out:
# /home/tford/.conda-envs/rpp/lib/python3.10/site-packages/xarray/core/dataset.py:274: UserWarning: The specified chunks separate the stored chunks along dimension "phony_dim_1" starting at index 500. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# /home/tford/.conda-envs/rpp/lib/python3.10/site-packages/xarray/core/dataset.py:274: UserWarning: The specified chunks separate the stored chunks along dimension "phony_dim_1" starting at index 500. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# /home/tford/.conda-envs/rpp/lib/python3.10/site-packages/xarray/core/dataset.py:274: UserWarning: The specified chunks separate the stored chunks along dimension "phony_dim_1" starting at index 500. This could degrade performance. Instead, consider rechunking after loading.
#   warnings.warn(
# ...
